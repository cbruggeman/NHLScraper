# %%
import urllib

# %%
from NHLScrape import *

# %%
NHLScrape.parsePlayByPlay(urllib.urlopen("http://www.nhl.com/scores/htmlreports/20142015/PL021053.HTM").read())

# %%
NHLScrape
# Out:
# <module 'NHLScrape' from 'NHLScrape.py'>

# %%
'%04d' % 5
# Out:
# '0005'

# %%
toidf=parseTOI(urllib.urlopen('http://www.nhl.com/scores/htmlreports/20142015/TV021051.HTM').read())

# %%
dir(toidf)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__idiv__',
#  '__imul__',
#  '__init__',
#  '__invert__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdiv__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
# ...

# %%
toidf['firstName'].unique()
# Out:
# array(['KEVIN', 'JACK', 'RYAN', 'CAM', 'COREY', 'CURTIS', 'RENE', 'JARED',
#        'ALEXANDER', 'ARTEM', 'SCOTT', 'DALTON', 'FEDOR', 'MARK', 'MARKO',
#        'DAVID', 'NICK'], dtype=object)

# %%
int(toidf['gameNumber'].values[0])
# Out:
# 1051

# %%
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-70-6cc5a375ea86> in <module>()
# ----> 1 pd.Series(toidf[['firstName','lastName','playerNumber']].values )
#
# /Users/Cam/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in __init__(self, data, index, dtype, name, copy, fastpath)
#     227             else:
#     228                 data = _sanitize_array(data, index, dtype, copy,
# --> 229                                        raise_cast_failure=True)
#     230
#     231                 data = SingleBlockManager(data, index, fastpath=True)
#
# /Users/Cam/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    2505     elif subarr.ndim > 1:
#    2506         if isinstance(data, pa.Array):
# -> 2507             raise Exception('Data must be 1-dimensional')
#    2508         else:
# ...

# %%
list(toidf['shiftEnd'].values)
# Out:
# [117,
#  263,
#  390,
#  549,
#  664,
#  901,
#  1076,
#  1305,
#  1479,
#  1606,
#  1696,
#  1933,
#  2157,
#  2293,
#  2520,
#  2619,
#  2723,
#  2945,
#  3053,
#  3186,
#  3374,
#  3461,
#  3616,
#  3778,
#  3900,
#  62,
#  221,
#  360,
#  443,
#  594,
#  732,
#  819,
#  984,
#  1156,
#  1372,
#  1517,
#  1648,
#  1753,
#  1860,
#  2002,
#  2243,
#  2400,
#  2488,
#  2601,
#  2691,
#  2839,
#  3009,
#  3132,
#  3267,
#  3402,
#  3582,
#  3642,
#  3852,
#  163,
#  656,
#  1082,
#  1454,
#  1708,
#  2331,
#  2574,
#  2723,
#  3009,
#  3210,
#  62,
#  263,
#  360,
#  509,
#  617,
#  732,
#  819,
#  901,
#  1156,
#  1345,
#  1430,
#  1580,
#  1753,
#  1860,
#  2040,
#  2218,
#  2461,
#  2619,
#  2684,
#  2917,
#  3095,
#  3267,
#  3402,
#  3527,
#  3616,
#  3888,
#  62,
#  263,
#  360,
#  509,
#  617,
#  732,
#  901,
#  1156,
#  1200,
#  1305,
#  1430,
#  1580,
#  1753,
#  1860,
#  2090,
#  2218,
#  2478,
#  2619,
#  2691,
#  2775,
#  2945,
#  3095,
#  3267,
#  3402,
#  3534,
# ...

# %%
nums=toidf['playerNumber'].unique()
nums[1]
# Out:
# '7'

# %%
for num in nums:
    print num
# Out:
# 4
# 7
# 12
# 13
# 19
# 26
# 27
# 30
# 32
# 40
# 41
# 42
# 43
# 47
# 51
# 55
# 56
# 58
# 71

# %%
processGame(2014)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-99-40a65378f3b3> in <module>()
# ----> 1 processGame(2014)
#
# NameError: name 'processGame' is not defined

# %%
import NHLScrape

# %%
dir(NHLScrape)
# Out:
# ['__builtins__',
#  '__doc__',
#  '__file__',
#  '__name__',
#  '__package__',
#  'convertTime',
#  'np',
#  'parsePlayByPlay',
#  'parseTOI',
#  'pd',
#  're',
#  'urllib']

# %%
tempdf=toidf[toidf['playerNumber']=='4'][['shiftStart','shiftEnd']]

# %%
tempdf['shiftStart']=(1,4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-126-db5e0420646b> in <module>()
# ----> 1 tempdf['shiftStart']=(1,4)
#
# /Users/Cam/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __setitem__(self, key, value)
#    2005         else:
#    2006             # set column
# -> 2007             self._set_item(key, value)
#    2008
#    2009     def _setitem_slice(self, key, value):
#
# /Users/Cam/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _set_item(self, key, value)
#    2083         is_existing = key in self.columns
#    2084         self._ensure_valid_index(value)
# -> 2085         value = self._sanitize_column(key, value)
#    2086         NDFrame._set_item(self, key, value)
#    2087
#
# /Users/Cam/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _sanitize_column(self, key, value)
# ...

# %%
tempdf
# Out:
#    shiftStart  shiftEnd
# 0           4       117
# 0           4       263
# 0           4       390
# 0           4       549
# 0           4       664
# 0           4       901
# 0           4      1076
# 0           4      1305
# 0           4      1479
# 0           4      1606
# 0           4      1696
# 0           4      1933
# 0           4      2157
# 0           4      2293
# 0           4      2520
# 0           4      2619
# 0           4      2723
# 0           4      2945
# 0           4      3053
# 0           4      3186
# 0           4      3374
# 0           4      3461
# 0           4      3616
# 0           4      3778
# 0           4      3900

# %%
toidf
# Out:
#    firstName                   gameDate gameNumber   lastName playerNumber  \
# 0      KEVIN  Wednesday, March 18, 2015       1051  CONNAUTON            4
# 0      KEVIN  Wednesday, March 18, 2015       1051  CONNAUTON            4
# 0      KEVIN  Wednesday, March 18, 2015       1051  CONNAUTON            4
# 0      KEVIN  Wednesday, March 18, 2015       1051  CONNAUTON            4
# 0      KEVIN  Wednesday, March 18, 2015       1051  CONNAUTON            4
# 0      KEVIN  Wednesday, March 18, 2015       1051  CONNAUTON            4
# 0      KEVIN  Wednesday, March 18, 2015       1051  CONNAUTON            4
# 0      KEVIN  Wednesday, March 18, 2015       1051  CONNAUTON            4
# 0      KEVIN  Wednesday, March 18, 2015       1051  CONNAUTON            4
# 0      KEVIN  Wednesday, March 18, 2015       1051  CONNAUTON            4
# 0      KEVIN  Wednesday, March 18, 2015       1051  CONNAUTON            4
# ...

# %%
pd.DataFrame({'A':[set({1})],
              'B':[1,6]})
# Out:
#           A  B
# 0  set([1])  1
# 1  set([1])  6

# %%
(4,3)*2
# Out:
# (4, 3, 4, 3)

# %%
[set({1})]
# Out:
# [{1}]

# %%
A=[set({1})]*2

# %%
A
# Out:
# [{1}, {1}]

# %%
A[1].add(5)

# %%
A
# Out:
# [{1, 5}, {1, 5}]
